# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", None)

# %%
date_columns = [
    "order_time",
    "order_date",
    "allot_time",
    "accept_time",
    "pickup_time",
    "delivered_time",
    "cancelled_time"
]

df = pd.read_csv(
    "../data/cleaned/food_delivery_cleaned.csv",
    parse_dates=date_columns
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450000 entries, 0 to 449999
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   order_time                  450000 non-null  datetime64[ns]
#  1   order_id                    450000 non-null  int64
#  2   order_date                  450000 non-null  datetime64[ns]
#  3   allot_time                  450000 non-null  datetime64[ns]
#  4   accept_time                 449843 non-null  datetime64[ns]
#  5   pickup_time                 447579 non-null  datetime64[ns]
#  6   delivered_time              444782 non-null  datetime64[ns]
#  7   rider_id                    450000 non-null  int64
#  8   first_mile_distance         450000 non-null  float64
#  9   last_mile_distance          450000 non-null  float64
#  10  alloted_orders              433052 non-null  float64
#  11  delivered_orders            432659 non-null  float64
#  12  cancelled                   450000 non-null  int64
#  13  undelivered_orders          432659 non-null  float64
#  14  lifetime_order_count        449947 non-null  float64
#  15  reassignment_method         449991 non-null  object
#  16  reassignment_reason         450000 non-null  object
#  17  reassigned_order            450000 non-null  float64
#  18  session_time                446325 non-null  float64
#  19  cancelled_time              5218 non-null    datetime64[ns]
#  20  assignment_delay_min        450000 non-null  float64
#  21  acceptance_time_min         449843 non-null  float64
#  22  preparation_time_min        447579 non-null  float64
#  23  delivery_time_min           444782 non-null  float64
#  24  total_fulfillment_time_min  444782 non-null  float64
#  25  cancellation_delay_min      5218 non-null    float64
#  26  total_distance              450000 non-null  float64
#  27  order_hour                  450000 non-null  int64
#  28  day_of_week                 450000 non-null  object
#  29  is_weekend                  450000 non-null  bool
# dtypes: bool(1), datetime64[ns](7), float64(15), int64(4), object(3)
# memory usage: 100.0+ MB

# %%
df.columns
# Out:
# Index(['order_time', 'order_id', 'order_date', 'allot_time', 'accept_time',
#        'pickup_time', 'delivered_time', 'rider_id', 'first_mile_distance',
#        'last_mile_distance', 'alloted_orders', 'delivered_orders', 'cancelled',
#        'undelivered_orders', 'lifetime_order_count', 'reassignment_method',
#        'reassignment_reason', 'reassigned_order', 'session_time',
#        'cancelled_time', 'assignment_delay_min', 'acceptance_time_min',
#        'preparation_time_min', 'delivery_time_min',
#        'total_fulfillment_time_min', 'cancellation_delay_min',
#        'total_distance', 'order_hour', 'day_of_week', 'is_weekend'],
#       dtype='object')

# %%
df['cancelled'].value_counts()
# Out:
# cancelled
# 0    444782
# 1      5218
# Name: count, dtype: int64
